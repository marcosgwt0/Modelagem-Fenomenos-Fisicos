# %% [markdown]
# <a href="https://colab.research.google.com/github/marcosgwt0/Modelagem-Fenomenos-Fisicos/blob/main/Copy_of_Atividade_Avaliativa_Individual_RA3_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Atenção: Regras para a solução da atividade.**
#
# 1. copie este caderno para a sua conta, criando as células de texto e código que forem necessárias após o enunciado de cada questão;
#
# 2. não apague os enunciados;
#
# 3. responda as questões na ordem em que elas se apresentam neste caderno;
#
# 4. você pode, e deve, consultar todo e qualquer recurso disponível na internet. Mas, não pode consultar nenhum outro ser humano.
#
# 5. poste no AVA (Canvas) o link para a sua resposta. Pode ser um link para a solução no Google Colab, ou um link para o caderno com suas respostas no Github.
#
# A violação de qualquer uma destas regras provoca a anulação da avaliação.
#
# Qualquer link que não possa ser executado a partir do link postado irá zerar a avaliação.
#
# Qualquer link que leve a uma pasta, arquivo comprimido, ou qualquer outro destino que não seja um caderno executável com as suas repostas provocará a anulação da questão.
#
# **Teste usando outro navegador que não esteja logado nas suas contas**.
#
# Qualquer link que não possa ser aberto, irá zerar a avaliação.
#
# Qualquer comunicação com outro ser humano irá zerar a avaliação.
#
# **A interpretação faz parte da Questão!!!**

# %% [markdown]
# # Questão 1 (vale até 2 pontos)
# Determine a área entre as curvas $$y=xe^{-x^{2}}$$ $$y=x+1$$ $$x=2$$ e o eixo $y$, usando somente matplotlib, numpy, sympy. Trace o gráfico desta área preenchendo a área entre as curvas em uma cor diferente.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir as funções
f1 = lambda x: x * np.exp(-x**2)
f2 = lambda x: x + 1

# Definir o intervalo
x = np.linspace(0, 2, 100)

# Calcular os valores das funções
y1 = f1(x)
y2 = f2(x)

# Plotar as curvas
plt.plot(x, y1, label='$y = x e^{-x^2}$')
plt.plot(x, y2, label='$y = x + 1$')

# Preencher a área entre as curvas com uma cor diferente
plt.fill_between(x, np.minimum(y1, y2), np.maximum(y1, y2), color='gray', alpha=0.5)

# Configurar o gráfico
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.xlim(0, 2)
plt.ylim(bottom=0)
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

# Exibir o gráfico
plt.show()

# %% [markdown]
# # Questão 2 (vale até 2 pontos)
# Resolva, algebricamente, explicitando em latex todos os passos necessários, as seguintes integrais:
#
# ##a)
# $$\int \cos(3t) \sin(8t) dt $$
# ##b)
# $$\int 4x \cos(2-3x) dx$$

# %% [markdown]
# ###a)

# %% [markdown]
# Começamos aplicando a identidade trigonométrica $\sin(a) \cos(b) = \frac{1}{2} (\sin(a+b) + \sin(a-b))$ para obter:
#
# \begin{align}
# \int \cos(3t) \sin(8t) , dt &= \frac{1}{2} \int \left( \sin(3t+8t) + \sin(3t-8t) \right) , dt \\
# &= \frac{1}{2} \int \left( \sin(11t) + \sin(-5t) \right) , dt \\
# &= \frac{1}{2} \int \left( \sin(11t) - \sin(5t) \right) , dt \\
# &= -\frac{1}{2} \left( \cos(11t) - \cos(5t) \right) + C \\
# &= -\frac{1}{2} \cos(5t) - \frac{1}{22} \cos(11t) + C
# \end{align}

# %% [markdown]
# ###b)

# %% [markdown]
# \begin{equation}
# \begin{aligned}
# \int 4x \cos(2-3x) \, dx \\
# \text{Remover a constante:} \\
# \int a \cdot f(x) \, dx = a \cdot \int f(x) \, dx \\
# = 4 \cdot \int x \cos(2-3x) \, dx \\
# \text{Aplicar integração por partes:} \\
# = 4 \left( -\frac{1}{3}x \sin(2-3x) - \int -\frac{1}{3} \sin(2-3x) \, dx \right) \\
# \int -\frac{1}{3} \sin(2-3x) \, dx = -\frac{1}{9} \cos(2-3x) \\
# = 4 \left( -\frac{1}{3}x \sin(2-3x) - \left( -\frac{1}{9} \cos(2-3x) \right) \right) \\
# \text{Simplificar:} \\
# = 4 \left( -\frac{1}{3}x \sin(2-3x) + \frac{1}{9} \cos(2-3x) \right) \\
# \text{Adicionar uma constante à solução:} \\
# = 4 \left( -\frac{1}{3}x \sin(2-3x) + \frac{1}{9} \cos(2-3x) \right) + C
# \end{aligned}
# \end{equation}

# %% [markdown]
# # Questão 3 (vale até 4 pontos)
# Calcule o valor das integrais definidas explicitadas a seguir. Trace o gráfico das funções que foram integradas e das funções encontradas após a integração destacando, com linhas verticais, os limites de integração.
#
# ##a)
# $$\int_0^2 x^2+1 \space dx$$
#
# ##b)
# $$\int_{-3}^1 6x^2-5x+2 \space dx$$

# %% [markdown]
# ###a)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Função a ser integrada
def f(x):
    return x**2 + 1

# Limites de integração
a = 0
b = 2

# Cálculo da integral definida
integral_definida = (1/3)*(b**3) + b - ((1/3)*(a**3) + a)


# Criação do intervalo de x
x = np.linspace(a, b, 100)

# Valores da função integrada
y = x**2 + 1

# Plot do gráfico da função integrada
plt.plot(x, y, label='x^2 + 1')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfico da função integrada')
plt.legend()

# Linhas verticais para os limites de integração
plt.axvline(x=a, color='r', linestyle='--', label='Limite inferior')
plt.axvline(x=b, color='g', linestyle='--', label='Limite superior')

plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ###b)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Função a ser integrada
def f(x):
    return 6*x**2 - 5*x + 2

# Limites de integração
a = -3
b = 1

# Cálculo da integral definida
integral_definida = (2*b**3 - (5/2)*b**2 + 2*b) - (2*a**3 - (5/2)*a**2 + 2*a)

print("Valor da integral definida:", integral_definida)

# Criação do intervalo de x
x = np.linspace(a, b, 100)

# Valores da função integrada
y = 6*x**2 - 5*x + 2

# Plot do gráfico da função integrada
plt.plot(x, y, label='6x^2 - 5x + 2')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfico da função integrada')
plt.legend()

# Linhas verticais para os limites de integração
plt.axvline(x=a, color='r', linestyle='--', label='Limite inferior')
plt.axvline(x=b, color='g', linestyle='--', label='Limite superior')

plt.legend()
plt.grid(True)
plt.show()
# Out:
# Valor da integral definida: 84.0

# %% [markdown]
# #Questão 4 (vale até 1 ponto)
# A taxa de variação de juros nos primeiros meses do ano de 2023 é dada por $v = 3t^2 - e^t$. Onde $t$ é o tempo dado em dias. Encontre a função que determina o juro, $j$ a ser pago em um determinado dia deste período de forma algébrica em latex.

# %% [markdown]
# \begin{align*}
# \text{Passo 1: Escrever a taxa de variação de juros em relação ao tempo} \\
# v &= 3t^2 - e^t \\
# \\
# \text{Passo 2: Integrar a taxa de variação em relação ao tempo para encontrar o juro} \\
# j &= \int v \, dt \\
# j &= \int (3t^2 - e^t) \, dt \\
# \\
# \text{Passo 3: Integrar cada termo separadamente} \\
# j &= \int 3t^2 \, dt - \int e^t \, dt \\
# \\
# \text{Passo 4: Realizar as integrações} \\
# j &= t^3 - e^t + C \\
# \\
# \text{Portanto, a função que determina o juro a ser pago em um determinado dia é:} \\
# j(t) &= t^3 - e^t + C \\
# \end{align*}

# %% [markdown]
# #Questão 5 (vale até 1 ponto)
# Encontre o valor da constante C para a antiderivada $F(x)$ da função $f(x) = 3x^3 - 2x + 1$ de tal forma que $F(1)=0$. Apresente seus cálculos em latex e explique as decisões que tomou.

# %% [markdown]
# \begin{align*}
# \text{Passo 1: Encontrar a antiderivada de } f(x) &= 3x^3 - 2x + 1 \\
# F(x) &= \int (3x^3 - 2x + 1) \, dx \\
# &= \frac{3}{4}x^4 - \frac{2}{2}x^2 + x + C \\
# &= \frac{3}{4}x^4 - x^2 + x + C
# \end{align*}
#
# \begin{align*}
# \text{Passo 2: Utilizar a condição } F(1) = 0 \text{ para encontrar o valor de C} \\
# \text{Substituindo } x = 1 \text{ em } F(x) \text{ e igualando a zero:} \\
# F(1) = \frac{3}{4}(1)^4 - (1)^2 + (1) + C = 0 \\
# \frac{3}{4} - 1 + 1 + C = 0 \\
# \frac{3}{4} + C = 0 \\
# C = -\frac{3}{4}\\
# \end{align*}
#
# \begin{align*}
# & \text{No primeiro passo, utilizamos as regras básicas de integração para encontrar a antiderivada de } f(x). \\
# & \text{Aplicamos a regra da potência para cada termo da função e somamos uma constante de integração C.} \\
# & \text{Essa constante C é adicionada na antiderivada porque a derivação de uma constante é igual a zero.}
# \end{align*}
#
#
#
#
# \begin{align*}
# & \text{No segundo passo, aplicamos a condição } F(1) = 0 \text{ na antiderivada encontrada no passo anterior.} \\
# & \text{Substituímos } x \text{ por } 1 \text{ e igualamos a expressão a zero.} \\
# & \text{Isso nos permite determinar o valor de C que satisfaça essa condição específica.} \\
# & \text{Simplificamos a equação resultante e isolamos a constante C.} \\
# & \text{Dessa forma, encontramos o valor exato de C que torna a antiderivada F(x) satisfazendo a condição } F(1) = 0.
# \end{align*}
